# %% [markdown]
# <div style="background:#e5e5e5; color:#000; padding:10px">
#
# Привет еще раз!\
# Декомпозиция принята!  Можно приступать к основному проекту.
#
# </div>

# %% [markdown]
# <div style="border:solid black 2px; padding: 20px">
# Максим, привет!
#
# Меня зовут Сергей, и я тимлидом на твоем выпускном проекте. Давай будем общаться на «ты». Но если тебе комфортнее на «вы», обязательно сообщи мне об этом.
#
# Свои комментарии я буду выделять следующим образом:
# <div class="alert alert-danger">
#
#   <b>Комментарий тимлида</b>
#
#   ❌ Так выделено то, что необходимо исправить, прежде чем я смогу принять твой проект.
# </div>
#
#
# <div class="alert alert-warning">
#
#   <b>Комментарий тимлида</b>
#
#   ⚠️ Так отмечены не обязательные к доработке моменты. Mожешь учесть их при редактировании проекта. На твое усмотрение.
# </div>
#
#
# <div class="alert alert-success">
#
#   <b>Комментарий тимлида</b>
#
#   ✔️ А так удачные решения и подходы, на которые стоит опираться в будущих проектах.
# </div>
#
#
# <div style="border:solid black 2px; padding: 20px">
#
#
#   <b>Чек-лист доработок</b>
#
#   📃 Такой комментарий будет в конце тетрадки. В нем будут еще раз указаны нюансы, требующие обязательного исправления.
# </div>
#
# Предлагаю работать над проектом в форме диалога: если ты <b>что-то меняешь</b> в работе по моим рекомендациям — <b>напиши об этом</b> в ячейке `Markdown` и помечай комментарий каким-то заметным цветом, например так:
#
#
# ```
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Текст комментария.
# </div>
# ```
#
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Текст комментария.
# </div>
#
# Пожалуйста, <b>не перемещай, не изменяй и не удаляй мои комментарии</b>. Такой формат работы поможет выполнить повторную проверку твоего проекта оперативнее.
#
# </div>

# %% [markdown]
# # Декомпозиция выявления профиля потребителя

# %% [markdown]
# # Контекст

# %% [markdown]
# Интернет-магазин товаров для дома «Пока все ещё тут» в срочном порядке ищет аналитиков. Мы поможем магазину стать лучше, а клиентам — обустроить дом своей мечты. Наши ближайшие задачи — расчёт метрик и создание гипотез на основе полученных данных.
#
# «Пока все ещё тут» — мы создаём уют!

# %% [markdown]
# **Задача** - Сегментировать покупателей по профилю потребления
#
# **Описание данных:**
#
#
# * `date` — дата заказа;
# * `customer_id` — идентификатор покупателя;
# * `order_id` — идентификатор заказа;
# * `product` — наименование товара;
# * `quantity` — количество товара в заказе;
# * `price` — цена товара.

# %% [markdown]
# <div class="alert alert-success">
#
#   <b>Комментарий тимлида</b>
#
#   ✔️ Хорошо, что есть название и цели проекта.
# </div>
# <div class="alert alert-danger">
#
#   <b>Комментарий тимлида</b>
#
#   ❌ Надо добавить и небольшое описание проекта.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Добавил краткое введение
# </div>
# <div class="alert alert-success">
#
#   <b>Комментарий тимлида v.2</b>
#
#   ✔️ Описание проекта есть.
# </div>

# %% [markdown]
#     1) Импорт и предобработка данных
#     2) Разделение пользователй по покупкам
#         2.1) Присвоение каждому товару соответствующей категории
#         2.2) Расчет выручки в каждой товарной категории
#         2.3) Определение количества заказов по каждой из категории
#         2.4) Количественный расчет заказов по категориям
#         2.5) Проверка гипотез
#             2.5.1) H0 - средний чек между товарными группами не отличается
#                    H1 - средний чек между товарными группами отличается
#             2.5.2) H0 - общая выручка между товарными группами не отличается
#                    H1 - общая выручка между товарными группами отличается
#         2.6) Выводы по блоку
#     3) Разделение пользователей по платежеспосбности
#         3.1) Присвоение каждому товару категории прибыльности
#         3.2) Расчет среднего чека в подгруппах
#         3.3) Проверка гипотез
#             3.3.1) Н0 - Средний чек не различается в зависимости от категории прибыльности товара
#                    Н1 - Средний чек различается в зависимости от категории прибыльности товара
#         3.4) Выводы по блоку
#     4) Вывод по проекту

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий тимлида</b>
#
#
#   ❌ У нас и там мало данных и период чуть больше года, не стоит выкидывать покупателей по дате.
#
#   ❌ Мы проводим сегментацию пользователей по покупкам, о чем я говорил на вебинаре, категории товара и их сезонность мы рассматриваем уже по получившимся сегментам. При сегментации по товарным категориям мы не видим, например, покупателей купивших только один дешевый товар - рассылка рекламы таким клиентам явно не окупится, или потенциальных оптовиков - на которых стоит заострить внимание.
#
#
#   ❌ Гипотезами мы проверяем корректность получившихся сегментов покупателей, а не время года, категории торовов и т.д. Т.е. средний чек по сегментам отличается\не отличается и т.п.
#
#
# И лучше сразу сформулировать нулевую и альтернативную гипотезы, например:
# - H0 - Нет различий между....
# - H1 - Есть различия между....
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента</b>
#
#   Удалил пункт про удаление данных неактивынх пользователей
#   Переписал декомпозицию с нуля в соответствии с предъявленными замечаниями
#
# </div>
# <div class="alert alert-danger">
#
#   <b>Комментарий тимлида v.2</b>
#
#
#   ❌ Наша цель - сегментация покупателей, категории товара и их сезонность мы смотрим уже по получившимся сегментам покупателей.
#
#   ❌ Гипотезами мы проверяем корректность получившихся сегментов покупателей, а не категории торовов и т.д.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
#
#   <b>Комментарий cтудента V2</b>
#
#   Переписал декомпозицию с нуля в соответствии с предъявленными замечаниями
#
# </div>
# <div class="alert alert-danger">
#
#   <b>Комментарий тимлида v.3</b>
#
#   ❌ Давай подробней распишем шаг сегментации, по каким данным? Лучше сейчас выявим возможные ошибки, чем уже при работе с проектом.
#
# </div>

# %% [markdown]
#     1) Импорт и предобработка данных
#     2) Категоризация товаров
#     3) Общий анализ данных
#         3.1) Изучение актвности покупателей за период
#         3.2) Изучение выручки, принесенной покупателями за год
#         3.3) Промежуточные выводы
#     4) Сегментация покупателей
#         4.1) При помощи алгоритма K-means предположить сегменты покупателей*
#         4.2) Изучить статистику по сегментам
#         4.3) Промежуточные выводы
#     5) Проверка гипотез
#         5.1) H0 - средний чек между группами потребителей не отличается
#              H1 - средний чек между группами потребителей отличается
#         5.2) H0 - общая выручка между группами потребителей не отличается
#              H1 - общая выручка между группами потребителей отличается
#     6) Проверка зависимостей
#         6.1) Проверка зависимости между продажами товаров в категории и сезона
#         6.2) Проверка зависимости продаж между потребительской группой и сезоном
#     7) Общие выводы и рекомендации
#
# * Опираясь на ассортимент и объёмы покупок, "Пока все ещё тут" - обычный магазин. Разделение методом K-means произведу на основе построенной дендрограммы. Б. Для этого использую четыре основные метрики:
#     * Средний чек
#     * Среднее кол-во заказов
#     * Среднее кол-во позиций в заказе
#     * Среднее LTV

# %% [markdown]
# <div class="alert alert-danger">
#
#   <b>Комментарий тимлида v.4</b>
#
#   ❌ При сегментации  K-means мы не сами задаем количество кластеров, а определяем их количество, например построив дендограмму или применив метод локтя.
#
# </div>

# %%
import pandas as pd
df_left = pd.DataFrame({'id': [1, 2, 3], 'name': ['Alice', 'Bob', 'Charlie'], 'value': [10, 20, 30]})
df_right = pd.DataFrame({'id': [2, 3, 4], 'city': ['Moscow', 'St. Petersburg', 'Kazan'], 'country': ['Russia', 'Russia', 'Russia']})

# Объединение датафреймов по столбцу 'id'
df = df_left.merge(df_right, on='id', how='inner')

# %%
df
# Out:
#    id     name  value            city country
# 0   2      Bob     20          Moscow  Russia
# 1   3  Charlie     30  St. Petersburg  Russia

# %%
import pandas as pd

# Пример данных
df_left = pd.DataFrame({'A': [10, 20, 30], 'index': ['a', 'b', 'c']})
df_right = pd.DataFrame({'B': [40, 50, 60], 'index': ['b', 'c', 'd']})
print(df_left)
print(df_right)
# Объединение датафреймов по индексам
df = df_left.merge(df_right, left_index=True, right_index=True, how='inner')

print(df)
# Out:
#     A index
# 0  10     a
# 1  20     b
# 2  30     c
#     B index
# 0  40     b
# 1  50     c
# 2  60     d
#     A index_x   B index_y
# 0  10       a  40       b
# 1  20       b  50       c
# 2  30       c  60       d
